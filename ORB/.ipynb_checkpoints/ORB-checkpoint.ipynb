# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure
from helpers import imshow

# %%
def orbTrack(trainImg,trainKP,trainDesc,QueryImgBGR,h,w):
    MIN_MATCH_COUNT=50

    detector=cv2.ORB_create()

    FLANN_INDEX_KDITREE=0
    flannParam=dict(algorithm=FLANN_INDEX_KDITREE,tree=5)
    searchParam = dict(checks=50)
    #flann=cv2.FlannBasedMatcher(flannParam,searchParam)
    flann=cv2.FlannBasedMatcher(flannParam,{})

    #trainImg=cv2.imread("demo0.png",0)
    #trainKP,trainDesc=detector.detectAndCompute(trainImg,None)

    #cam=cv2.VideoCapture(0)
    #while True:
    #ret, QueryImgBGR=cam.read()
    
    QueryImg=cv2.cvtColor(QueryImgBGR,cv2.COLOR_BGR2GRAY)
    queryKP,queryDesc=detector.detectAndCompute(QueryImg,None)
    matches=flann.knnMatch(queryDesc,trainDesc,k=2)

    goodMatch=[]
    queryBorder = None
    qp = None
    for m,n in matches:
        if(m.distance < 0.75*n.distance):
            goodMatch.append(m)
    if(len(goodMatch) > MIN_MATCH_COUNT):
        tp=[]
        qp=[]
        for m in goodMatch:
            tp.append(trainKP[m.trainIdx].pt)
            qp.append(queryKP[m.queryIdx].pt)
        tp,qp=np.float32((tp,qp))
        H,status=cv2.findHomography(tp,qp,cv2.RANSAC,3.0)
        
        #h,w=trainImg.shape
        trainBorder=np.float32([[[0,0],[0,h-1],[w-1,h-1],[w-1,0]]])
        queryBorder=cv2.perspectiveTransform(trainBorder,H)
        cv2.polylines(QueryImgBGR,[np.int32(queryBorder)],True,(0,255,0),5)
        return (1,queryBorder,qp)
        #print(queryBorder)
    else:
        #print("Not Enough match found")
        return (-1,queryBorder,qp)

# %%
def findOrientation(qp):
    tl = qp[0][0] #top left
    bl = qp[0][1] #botton left
    br = qp[0][2] #botton right
    tr = qp[0][3] #top right
    center = [(t1[0]+br[0])/2,(t1[1]+br[1])/2]
    theta = None
    #center is the center of the detected object
    #theta is the angle of it
    return center,theta

# %%
cam = cv2.VideoCapture(0)
img1 = cv2.imread("demo.jpg")
h,w,d = img1.shape
detector = cv2.ORB_create()
kp1, des1 = detector.detectAndCompute(img1,None)
while True:
    ret, img2 = cam.read()
    checker,dst,qp = orbTrack(img1,kp1,des1,img2,h,w)
    if checker != -1:
        #center = findOrientation(qp)
        #res = cv2.resize(img, None, fx=2, fy=2, interpolation = cv.INTER_AREA)
        mask = cv2.polylines(img2,[np.int32(dst)],True,(0,255,0),5)
        print("YES")
    else:
        print("NO")
    keypressed = cv2.waitKey(5)
    if keypressed == 27:
        break
    cv2.imshow('mask',mask)
    
cam.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-33-79f21618845a> in <module>()
#       6 while True:
#       7     ret, img2=cam.read()
# ----> 8     checker,dst,qp = siftTrack(img1,kp1,des1,img2,h,w)
#       9     if checker != -1:
#      10         #center = findOrientation(qp)
#
# <ipython-input-31-d8be513aed8b> in siftTrack(trainImg, trainKP, trainDesc, QueryImgBGR, h, w)
#      19     QueryImg=cv2.cvtColor(QueryImgBGR,cv2.COLOR_BGR2GRAY)
#      20     queryKP,queryDesc=detector.detectAndCompute(QueryImg,None)
# ---> 21     matches=flann.knnMatch(queryDesc,trainDesc,k=2)
#      22
#      23     goodMatch=[]
#
# error: /Users/travis/build/skvark/opencv-python/opencv/modules/flann/src/miniflann.cpp:315: error: (-210) type=0
#  in function buildIndex_

# %%
import cv2
from matplotlib import pyplot as plt
from helpers import imshow

img = cv2.imread('demo.jpg')
orb = cv2.ORB_create()
kp, des = orb.detectAndCompute(img1,None)
img2 = cv2.drawKeypoints(img, kp, None, color=(0,255,0), flags=0)

# Initiate STAR detector
imshow(img2)
